# %%
import geonetwork 
import importlib

importlib.reload(geonetwork)
# Out:
# <module 'geonetwork' from '/python_src/importer/geonetwork.py'>

# %%
cap_xml = geonetwork.read_caps()

root = geonetwork.parse_caps(cap_xml)

# %%
root.tag

importlib.reload(geonetwork)

my_namespaces = geonetwork.get_namespaces(cap_xml)
from pprint import pprint

#pprint(my_namespaces)

geonetwork.get_operations_from_root(root, my_namespaces)

recs_xml = geonetwork.get_records()

# %%
importlib.reload(geonetwork)

print(geonetwork.pretty_print_xml(recs_xml))

# %%
importlib.reload(geonetwork)

print(geonetwork.pretty_print_xml(recs_xml))
# Out:
# <?xml version="1.0" ?>
# <csw:GetRecordsResponse xmlns:csw="http://www.opengis.net/cat/csw/2.0.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.opengis.net/cat/csw/2.0.2 http://schemas.opengis.net/csw/2.0.2/CSW-discovery.xsd">
# 	<csw:SearchStatus timestamp="2020-05-20T09:10:18"/>
# 	<csw:SearchResults numberOfRecordsMatched="37" numberOfRecordsReturned="10" elementSet="summary" nextRecord="11">
# 		<csw:SummaryRecord xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:geonet="http://www.fao.org/geonetwork" xmlns:dct="http://purl.org/dc/terms/">
# 			<dc:identifier>9c76da99-f2af-4024-bd32-c6e9f6478d8a</dc:identifier>
# 			<dc:title>Kano Operational Ward Boundaries</dc:title>
# 			<dc:subject>State Administrative Boundary</dc:subject>
# 			<dc:subject>Local Government Administrative Boundary</dc:subject>
# 			<dc:subject>Operational Ward Boundary</dc:subject>
# 			<dc:format>CSV</dc:format>
# 			<dc:format>GeoJSON</dc:format>
# ...
